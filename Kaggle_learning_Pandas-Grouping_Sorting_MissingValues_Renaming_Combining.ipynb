# %%
#Maps allow us to transform data in a DataFrame or Series one value at a time for an entire column. 
#However, often we want to group our data, and then do something specific to the group the data is in.

# %%
import pandas as pd

# %%
melbourne_file_path = 'Introduction_Machine_Learning_Data.csv'
melbourne_data = pd.read_csv(melbourne_file_path) 
melbourne_data.columns
reviews = melbourne_data

# %%
reviews
# Out:
#               Suburb           Address  Rooms Type      Price Method  \
# 0         Abbotsford      85 Turner St      2    h  1480000.0      S
# 1         Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 2         Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3         Abbotsford  40 Federation La      3    h   850000.0     PI
# 4         Abbotsford       55a Park St      4    h  1600000.0     VB
# ...              ...               ...    ...  ...        ...    ...
# 13575  Wheelers Hill      12 Strada Cr      4    h  1245000.0      S
# 13576   Williamstown     77 Merrett Dr      3    h  1031000.0     SP
# 13577   Williamstown       83 Power St      3    h  1170000.0      S
# 13578   Williamstown      96 Verdon St      4    h  2500000.0     PI
# 13579     Yarraville        6 Agnes St      4    h  1285000.0     SP
#
#         SellerG        Date  Distance  Postcode  ...  Bathroom  Car  Landsize  \
# ...

# %%
reviews.groupby('Rooms').Rooms.count()
# Out:
# Rooms
# 1      681
# 2     3648
# 3     5881
# 4     2688
# 5      596
# 6       67
# 7       10
# 8        8
# 10       1
# Name: Rooms, dtype: int64

# %%
reviews.groupby('Rooms').Price.min()
# Out:
# Rooms
# 1       85000.0
# 2      190000.0
# 3      283000.0
# 4      131000.0
# 5      355000.0
# 6      506000.0
# 7     1005000.0
# 8      741000.0
# 10     900000.0
# Name: Price, dtype: float64

# %%
#one way of selecting the name of the first Address reviewed from each Suburb in the dataset:
reviews.groupby('Suburb').apply(lambda df: df.Address.iloc[0])
# Out:
# Suburb
# Abbotsford           85 Turner St
# Aberfeldie      2/2 St Kinnord St
# Airport West        154 Halsey Rd
# Albanvale           28 Oakwood Rd
# Albert Park        105 Kerferd Rd
#                       ...
# Wonga Park       2 Rindlebrook Pl
# Wyndham Vale          5 Dakara Ct
# Yallambie          11 Tarcoola Dr
# Yarra Glen            15 Yarra St
# Yarraville           13 Benbow St
# Length: 314, dtype: object

# %%
Address_final = reviews.groupby(['Suburb', 'Address']).apply(lambda df: df.loc[df.Rooms.idxmax()])
Address_final
# Out:
#                                    Suburb             Address  Rooms Type  \
# Suburb     Address
# Abbotsford 1/43 Abbotsford St  Abbotsford  1/43 Abbotsford St      2    u
#            1/50 Valiant St     Abbotsford     1/50 Valiant St      4    t
#            10 James St         Abbotsford         10 James St      2    h
#            10 Valiant St       Abbotsford       10 Valiant St      2    h
#            101 Charles St      Abbotsford      101 Charles St      2    h
# ...                                   ...                 ...    ...  ...
# Yarraville 9/11 Berry St       Yarraville       9/11 Berry St      3    h
#            9/51 Stephen St     Yarraville     9/51 Stephen St      2    u
#            92 Simpson St       Yarraville       92 Simpson St      2    h
#            96 Hamilton St      Yarraville      96 Hamilton St      2    h
#            96 Pentland Pde     Yarraville     96 Pentland Pde      3    h
#
# ...

# %%
mi = Address_final.index
type(mi)
# Out:
# pandas.core.indexes.multi.MultiIndex

# %%
#agg() lets you run a bunch of different functions on your DataFrame simultaneously.
reviews.groupby(['Suburb']).Price.agg([len, min, max])
# Out:
#                 len       min        max
# Suburb
# Abbotsford     56.0  300000.0  1876000.0
# Aberfeldie     44.0  280000.0  3900000.0
# Airport West   67.0  440000.0  1250000.0
# Albanvale       6.0  415000.0   655000.0
# Albert Park    69.0  442500.0  4735000.0
# ...             ...       ...        ...
# Wonga Park      1.0  900000.0   900000.0
# Wyndham Vale    4.0  475000.0   500000.0
# Yallambie      24.0  602500.0  1670000.0
# Yarra Glen      1.0  620000.0   620000.0
# Yarraville    164.0  330000.0  2450000.0
#
# [314 rows x 3 columns]

# %%
trail_1 = reviews[['Suburb', 'Address']].groupby('Suburb').Address.min()

# %%
trail_1
# Out:
# Suburb
# Abbotsford      1/43 Abbotsford St
# Aberfeldie               1 Alma St
# Airport West      1/37 Hillside Gr
# Albanvale             10 Elinga Ct
# Albert Park           1 Moubray St
#                        ...
# Wonga Park        2 Rindlebrook Pl
# Wyndham Vale        11 Chisholm Pl
# Yallambie           11 Tarcoola Dr
# Yarra Glen             15 Yarra St
# Yarraville           1 Highgate St
# Name: Address, Length: 314, dtype: object

# %%
trail_2 = reviews[['Suburb', 'Address']].groupby('Suburb')['Address'].min()

# %%
trail_2
# Out:
# Suburb
# Abbotsford      1/43 Abbotsford St
# Aberfeldie               1 Alma St
# Airport West      1/37 Hillside Gr
# Albanvale             10 Elinga Ct
# Albert Park           1 Moubray St
#                        ...
# Wonga Park        2 Rindlebrook Pl
# Wyndham Vale        11 Chisholm Pl
# Yallambie           11 Tarcoola Dr
# Yarra Glen             15 Yarra St
# Yarraville           1 Highgate St
# Name: Address, Length: 314, dtype: object

# %%
trail_3 = reviews[['Suburb', 'Address']].groupby('Suburb')['Address'].shift()

# %%
trail_3
# Out:
# 0                     NaN
# 1            85 Turner St
# 2         25 Bloomburg St
# 3            5 Charles St
# 4        40 Federation La
#                ...
# 13575    2 Wattleglade Ct
# 13576     146 Ferguson St
# 13577       77 Merrett Dr
# 13578         83 Power St
# 13579       18 Stewart St
# Name: Address, Length: 13580, dtype: object

# %%
suburb_population = reviews.groupby(['Suburb']).Price.agg([len])

# %%
suburb_population
# Out:
#                 len
# Suburb
# Abbotsford     56.0
# Aberfeldie     44.0
# Airport West   67.0
# Albanvale       6.0
# Albert Park    69.0
# ...             ...
# Wonga Park      1.0
# Wyndham Vale    4.0
# Yallambie      24.0
# Yarra Glen      1.0
# Yarraville    164.0
#
# [314 rows x 1 columns]

# %%
#the multi-index method you will use most often is the one for converting back to a regular index, the reset_index() method:
suburb_population = suburb_population.reset_index()
# Out:
#            Suburb    len
# 0      Abbotsford   56.0
# 1      Aberfeldie   44.0
# 2    Airport West   67.0
# 3       Albanvale    6.0
# 4     Albert Park   69.0
# ..            ...    ...
# 309    Wonga Park    1.0
# 310  Wyndham Vale    4.0
# 311     Yallambie   24.0
# 312    Yarra Glen    1.0
# 313    Yarraville  164.0
#
# [314 rows x 2 columns]

# %%
suburb_population.sort_values(by='len')
# Out:
#                   len
# Suburb
# Montrose          1.0
# Wallan            1.0
# Healesville       1.0
# Brookfield        1.0
# Sandhurst         1.0
# ...               ...
# Brunswick       222.0
# Preston         239.0
# Bentleigh East  249.0
# Richmond        260.0
# Reservoir       359.0
#
# [314 rows x 1 columns]

# %%
suburb_population.sort_values(by='len', ascending=False)
# Out:
#                       len
# Suburb
# Reservoir           359.0
# Richmond            260.0
# Bentleigh East      249.0
# Preston             239.0
# Brunswick           222.0
# ...                   ...
# Attwood               1.0
# Beaconsfield Upper    1.0
# Bacchus Marsh         1.0
# Sandhurst             1.0
# Officer               1.0
#
# [314 rows x 1 columns]

# %%
#Finally, know that you can sort by more than one column at a time:
suburb_population.sort_values(by=['Suburb','len'])
# Out:
#                 len
# Suburb
# Abbotsford     56.0
# Aberfeldie     44.0
# Airport West   67.0
# Albanvale       6.0
# Albert Park    69.0
# ...             ...
# Wonga Park      1.0
# Wyndham Vale    4.0
# Yallambie      24.0
# Yarra Glen      1.0
# Yarraville    164.0
#
# [314 rows x 1 columns]

# %%
#which suburb has the cheapest house
reviews.groupby('Suburb').Price.min().sort_values()
# Out:
# Suburb
# Footscray         85000.0
# Caulfield        131000.0
# Coburg           145000.0
# Albion           145000.0
# Hawthorn         160000.0
#                   ...
# Silvan          1070000.0
# Waterways       1232000.0
# Kooyong         1290000.0
# New Gisborne    1355000.0
# Princes Hill    1540000.0
# Name: Price, Length: 314, dtype: float64

# %%
reviews.groupby('Suburb').Price.min().sort_index()
# Out:
# Suburb
# Abbotsford      300000.0
# Aberfeldie      280000.0
# Airport West    440000.0
# Albanvale       415000.0
# Albert Park     442500.0
#                   ...
# Wonga Park      900000.0
# Wyndham Vale    475000.0
# Yallambie       602500.0
# Yarra Glen      620000.0
# Yarraville      330000.0
# Name: Price, Length: 314, dtype: float64

# %%
sorted_suburb = reviews.groupby('Suburb').Price.agg([min,max]).sort_values(by=['min','max'], ascending=False)

# %%
sorted_suburb
# Out:
#                     min        max
# Suburb
# Princes Hill  1540000.0  1908000.0
# New Gisborne  1355000.0  1355000.0
# Kooyong       1290000.0  3080000.0
# Waterways     1232000.0  1265000.0
# Silvan        1070000.0  1085000.0
# ...                 ...        ...
# Hawthorn       160000.0  7650000.0
# Coburg         145000.0  2250000.0
# Albion         145000.0   905000.0
# Caulfield      131000.0  1665000.0
# Footscray       85000.0  1450000.0
#
# [314 rows x 2 columns]

# %%
reviews.groupby(['Suburb']).Suburb.count()
# Out:
# Suburb
# Abbotsford       56
# Aberfeldie       44
# Airport West     67
# Albanvale         6
# Albert Park      69
#                ...
# Wonga Park        1
# Wyndham Vale      4
# Yallambie        24
# Yarra Glen        1
# Yarraville      164
# Name: Suburb, Length: 314, dtype: int64

# %%
reviews.groupby(['Suburb']).size()
# Out:
# Suburb
# Abbotsford       56
# Aberfeldie       44
# Airport West     67
# Albanvale         6
# Albert Park      69
#                ...
# Wonga Park        1
# Wyndham Vale      4
# Yallambie        24
# Yarra Glen        1
# Yarraville      164
# Length: 314, dtype: int64

# %%
reviews.Price.dtype
# Out:
# dtype('float64')

# %%
#It's possible to convert a column of one type into another wherever a conversion makes sense by using the astype() function
reviews.Price.astype('int64')
# Out:
# 0        1480000
# 1        1035000
# 2        1465000
# 3         850000
# 4        1600000
#           ...
# 13575    1245000
# 13576    1031000
# 13577    1170000
# 13578    2500000
# 13579    1285000
# Name: Price, Length: 13580, dtype: int64

# %%
reviews.Price.dtype
# Out:
# dtype('float64')

# %%
#A DataFrame or Series index has its own dtype
reviews.index.dtype
# Out:
# dtype('int64')

# %%
#Entries missing values are given the value NaN, short for "Not a Number". 
#For technical reasons these NaN values are always of the float64 dtype

#Pandas provides some methods specific to missing data. 
#To select NaN entries you can use pd.isnull() (or its companion pd.notnull()).

reviews[pd.isnull(reviews.BuildingArea)]
# Out:
#                Suburb             Address  Rooms Type      Price Method  \
# 0          Abbotsford        85 Turner St      2    h  1480000.0      S
# 3          Abbotsford    40 Federation La      3    h   850000.0     PI
# 5          Abbotsford      129 Charles St      2    h   941000.0      S
# 8          Abbotsford  6/241 Nicholson St      1    u   300000.0      S
# 10         Abbotsford  411/8 Grosvenor St      2    u   700000.0     VB
# ...               ...                 ...    ...  ...        ...    ...
# 13569  Wantirna South        12 Armagh Cr      4    h  1323000.0      S
# 13570  Wantirna South       34 Fewster Dr      3    h   970000.0      S
# 13574     Westmeadows          9 Black St      3    h   582000.0      S
# 13575   Wheelers Hill        12 Strada Cr      4    h  1245000.0      S
# 13577    Williamstown         83 Power St      3    h  1170000.0      S
#
#       SellerG        Date  Distance  Postcode  ...  Bathroom  Car  Landsize  \
# ...

# %%
(reviews.BuildingArea).isnull().sum()
# Out:
# 6450

# %%
pd.isnull(reviews.BuildingArea).sum()
# Out:
# 6450

# %%
#Replacing missing values is a common operation. Pandas provides a really handy method for this problem: fillna(). 
reviews.YearBuilt.fillna("Unknown")
# Out:
# 0        Unknown
# 1           1900
# 2           1900
# 3        Unknown
# 4           2014
#           ...
# 13575       1981
# 13576       1995
# 13577       1997
# 13578       1920
# 13579       1920
# Name: YearBuilt, Length: 13580, dtype: object

# %%
reviews
# Out:
#               Suburb           Address  Rooms Type      Price Method  \
# 0         Abbotsford      85 Turner St      2    h  1480000.0      S
# 1         Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 2         Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3         Abbotsford  40 Federation La      3    h   850000.0     PI
# 4         Abbotsford       55a Park St      4    h  1600000.0     VB
# ...              ...               ...    ...  ...        ...    ...
# 13575  Wheelers Hill      12 Strada Cr      4    h  1245000.0      S
# 13576   Williamstown     77 Merrett Dr      3    h  1031000.0     SP
# 13577   Williamstown       83 Power St      3    h  1170000.0      S
# 13578   Williamstown      96 Verdon St      4    h  2500000.0     PI
# 13579     Yarraville        6 Agnes St      4    h  1285000.0     SP
#
#         SellerG        Date  Distance  Postcode  ...  Bathroom  Car  Landsize  \
# ...

# %%
reviews.Suburb.replace("Abbotsford", "@Abbotsford")
# Out:
# 0          @Abbotsford
# 1          @Abbotsford
# 2          @Abbotsford
# 3          @Abbotsford
# 4          @Abbotsford
#              ...
# 13575    Wheelers Hill
# 13576     Williamstown
# 13577     Williamstown
# 13578     Williamstown
# 13579       Yarraville
# Name: Suburb, Length: 13580, dtype: object

# %%
reviews.describe()
# Out:
#               Rooms         Price      Distance      Postcode      Bedroom2  \
# count  13580.000000  1.358000e+04  13580.000000  13580.000000  13580.000000
# mean       2.937997  1.075684e+06     10.137776   3105.301915      2.914728
# std        0.955748  6.393107e+05      5.868725     90.676964      0.965921
# min        1.000000  8.500000e+04      0.000000   3000.000000      0.000000
# 25%        2.000000  6.500000e+05      6.100000   3044.000000      2.000000
# 50%        3.000000  9.030000e+05      9.200000   3084.000000      3.000000
# 75%        3.000000  1.330000e+06     13.000000   3148.000000      3.000000
# max       10.000000  9.000000e+06     48.100000   3977.000000     20.000000
#
#            Bathroom           Car       Landsize  BuildingArea    YearBuilt  \
# count  13580.000000  13518.000000   13580.000000   7130.000000  8205.000000
# mean       1.534242      1.610075     558.416127    151.967650  1964.684217
# ...

# %%
reviews.YearBuilt.fillna("Unknown").size().sort_values(ascending=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-110-08ff6656b019> in <module>
# ----> 1 reviews.YearBuilt.fillna("Unknown").size().sort_values(ascending=False)
#
# TypeError: 'int' object is not callable

# %%
reviews.YearBuilt.fillna("Unknown").value_counts().sort_values(ascending=False)
# Out:
# Unknown    5375
# 1970.0      866
# 1960.0      725
# 1950.0      580
# 1900.0      341
#            ...
# 1877.0        1
# 1854.0        1
# 1862.0        1
# 1856.0        1
# 1196.0        1
# Name: YearBuilt, Length: 145, dtype: int64

# %%
reviews.rename(columns={'Price': 'Cost'})
# Out:
#               Suburb           Address  Rooms Type       Cost Method  \
# 0         Abbotsford      85 Turner St      2    h  1480000.0      S
# 1         Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 2         Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3         Abbotsford  40 Federation La      3    h   850000.0     PI
# 4         Abbotsford       55a Park St      4    h  1600000.0     VB
# ...              ...               ...    ...  ...        ...    ...
# 13575  Wheelers Hill      12 Strada Cr      4    h  1245000.0      S
# 13576   Williamstown     77 Merrett Dr      3    h  1031000.0     SP
# 13577   Williamstown       83 Power St      3    h  1170000.0      S
# 13578   Williamstown      96 Verdon St      4    h  2500000.0     PI
# 13579     Yarraville        6 Agnes St      4    h  1285000.0     SP
#
#         SellerG        Date  Distance  Postcode  ...  Bathroom  Car  Landsize  \
# ...

# %%
reviews
# Out:
#               Suburb           Address  Rooms Type      Price Method  \
# 0         Abbotsford      85 Turner St      2    h  1480000.0      S
# 1         Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 2         Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3         Abbotsford  40 Federation La      3    h   850000.0     PI
# 4         Abbotsford       55a Park St      4    h  1600000.0     VB
# ...              ...               ...    ...  ...        ...    ...
# 13575  Wheelers Hill      12 Strada Cr      4    h  1245000.0      S
# 13576   Williamstown     77 Merrett Dr      3    h  1031000.0     SP
# 13577   Williamstown       83 Power St      3    h  1170000.0      S
# 13578   Williamstown      96 Verdon St      4    h  2500000.0     PI
# 13579     Yarraville        6 Agnes St      4    h  1285000.0     SP
#
#         SellerG        Date  Distance  Postcode  ...  Bathroom  Car  Landsize  \
# ...

# %%
reviews.rename(index={0: 'firstEntry', 1: 'secondEntry'})
# Out:
#                     Suburb           Address  Rooms Type      Price Method  \
# firstEntry      Abbotsford      85 Turner St      2    h  1480000.0      S
# secondEntry     Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 2               Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3               Abbotsford  40 Federation La      3    h   850000.0     PI
# 4               Abbotsford       55a Park St      4    h  1600000.0     VB
# ...                    ...               ...    ...  ...        ...    ...
# 13575        Wheelers Hill      12 Strada Cr      4    h  1245000.0      S
# 13576         Williamstown     77 Merrett Dr      3    h  1031000.0     SP
# 13577         Williamstown       83 Power St      3    h  1170000.0      S
# 13578         Williamstown      96 Verdon St      4    h  2500000.0     PI
# 13579           Yarraville        6 Agnes St      4    h  1285000.0     SP
#
# ...

# %%
reviews.rename_axis("index", axis='rows').rename_axis("fields", axis='columns')
# Out:
# fields         Suburb           Address  Rooms Type      Price Method  \
# index
# 0          Abbotsford      85 Turner St      2    h  1480000.0      S
# 1          Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 2          Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3          Abbotsford  40 Federation La      3    h   850000.0     PI
# 4          Abbotsford       55a Park St      4    h  1600000.0     VB
# ...               ...               ...    ...  ...        ...    ...
# 13575   Wheelers Hill      12 Strada Cr      4    h  1245000.0      S
# 13576    Williamstown     77 Merrett Dr      3    h  1031000.0     SP
# 13577    Williamstown       83 Power St      3    h  1170000.0      S
# 13578    Williamstown      96 Verdon St      4    h  2500000.0     PI
# 13579      Yarraville        6 Agnes St      4    h  1285000.0     SP
#
# fields   SellerG        Date  Distance  Postcode  ...  Bathroom  Car  \
# ...

# %%
#To combine different DataFrames and/or Series in non-trivial ways. 
#Pandas has three core methods for doing this. In order of increasing complexity, these are concat(), join(), and merge(). 
#Most of what merge() can do can also be done more simply with join(), 
#so we will omit it and focus on the first two functions here.

#The simplest method is concat(). Given a list of elements, this function will smush those elements together along an axis.
#This is useful when we have data in different DataFrame or Series objects but having the same fields (columns).

train_data = pd.read_csv("Intermediate_Machine_Learning_Train_Data.csv")
test_data = pd.read_csv("Intermediate_Machine_Learning_Test_Data.csv")

pd.concat([train_data, test_data])
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1454  2915         160       RM         21.0     1936   Pave   NaN      Reg
# 1455  2916         160       RM         21.0     1894   Pave   NaN      Reg
# 1456  2917          20       RL        160.0    20000   Pave   NaN      Reg
# 1457  2918          85       RL         62.0    10441   Pave   NaN      Reg
# 1458  2919          60       RL         74.0     9627   Pave   NaN      Reg
#
# ...

# %%
pd.concat([train_data, test_data], ignore_index=True)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 2914  2915         160       RM         21.0     1936   Pave   NaN      Reg
# 2915  2916         160       RM         21.0     1894   Pave   NaN      Reg
# 2916  2917          20       RL        160.0    20000   Pave   NaN      Reg
# 2917  2918          85       RL         62.0    10441   Pave   NaN      Reg
# 2918  2919          60       RL         74.0     9627   Pave   NaN      Reg
#
# ...

# %%
train_data.join(test_data, lsuffix='_train', rsuffix='_test')
# Out:
#       Id_train  MSSubClass_train MSZoning_train  LotFrontage_train  \
# 0            1                60             RL               65.0
# 1            2                20             RL               80.0
# 2            3                60             RL               68.0
# 3            4                70             RL               60.0
# 4            5                60             RL               84.0
# ...        ...               ...            ...                ...
# 1455      1456                60             RL               62.0
# 1456      1457                20             RL               85.0
# 1457      1458                70             RL               66.0
# 1458      1459                20             RL               68.0
# 1459      1460                20             RL               75.0
#
#       LotArea_train Street_train Alley_train LotShape_train LandContour_train  \
# 0              8450         Pave         NaN            Reg               Lvl
# ...

# %%
#Both tables include references to a MeetID, a unique key for each meet (competition) included in the database. 
#Using this, generate a dataset combining the two tables into one.

powerlifting_combined = powerlifting_meets.set_index("MeetID").join(powerlifting_competitors.set_index("MeetID"))
